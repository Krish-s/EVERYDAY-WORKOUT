# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Class notes/Datascience_dataset/SAMPLE.csv")

# %%
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
## DATA EXPLORATION

df.head()
# Out:
#    sl No name              college   hsc  SSLC  arrears  cmark
# 0    NaN  NaN                  NaN   NaN   NaN      NaN    NaN
# 1    1.0   A1                 IITM  89.9  92.6      0.0   95.0
# 2    2.0   A2      ANNA UNIVERSITY  76.8  77.9      3.0    NaN
# 3    3.0   A3      ANNA UNIVERSITY   NaN  85.6      6.0   99.0
# 4    4.0   A4  ANAMALAI UNIVERSITY  92.5  94.6      1.0   76.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sl No    17 non-null     float64
#  1   name     17 non-null     object
#  2   college  15 non-null     object
#  3   hsc      15 non-null     float64
#  4   SSLC     15 non-null     float64
#  5   arrears  16 non-null     float64
#  6   cmark    16 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
df.isnull().sum()
# Out:
# sl No      3
# name       3
# college    5
# hsc        5
# SSLC       5
# arrears    4
# cmark      4
# dtype: int64

# %%
df.columns
# Out:
# Index(['sl No', 'name', 'college', 'hsc', 'SSLC', 'arrears', 'cmark'], dtype='object')

# %%
df.shape
# Out:
# (20, 7)

# %%
df.dropna(inplace= True)

# %%
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df['college'].fillna('Unknown')
# Out:
# 0                 Unknown
# 1                    IITM
# 2         ANNA UNIVERSITY
# 3         ANNA UNIVERSITY
# 4     ANAMALAI UNIVERSITY
# 5                 Unknown
# 6                     SRM
# 7                SAVEETHA
# 8                SAVEETHA
# 9                SAVEETHA
# 10        ANNA UNIVERSITY
# 11                Unknown
# 12                Unknown
# 13    ANAMALAI UNIVERSITY
# 14                 fogjof
# 15                   IITM
# 16                Unknown
# 17              dhgvuicbh
# 18                    SRM
# 19        ANNA UNIVERSITY
# Name: college, dtype: object

# %%
df.drop_duplicates()
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df.rename(columns ={'SSLC':'Secondary Marks'})
# Out:
#     sl No name              college    hsc  Secondary Marks  arrears  cmark
# 1     1.0   A1                 IITM  89.90             92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50             94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80             88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80             65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80             99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70             91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00             77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90             84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90             97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39             85.6      6.0   99.0

# %%
## DATA MANIPULATION

df["avg_marks"]=df[['hsc','SSLC']].mean(axis=1)
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark  avg_marks
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0     91.250
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0     93.550
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6     93.950
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5     82.800
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5     99.800
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0     94.850
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0     85.800
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0     81.900
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0     91.950
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995

# %%
df[df['arrears']>2]
# Out:
#     sl No name          college    hsc  SSLC  arrears  cmark  avg_marks
# 8     8.0   A8         SAVEETHA  99.80  65.8     66.0   77.5     82.800
# 9    56.0  A34         SAVEETHA  99.80  99.8      5.0   77.5     99.800
# 17   13.0  A12        dhgvuicbh  78.90  84.9      3.0   83.0     81.900
# 18   14.0  A13              SRM  86.90  97.0     33.0   92.0     91.950
# 19    3.0   A3  ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995

# %%
df.sort_values(by=["cmark"], ascending=False)
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark  avg_marks
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0     91.250
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0     91.950
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6     93.950
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0     81.900
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5     82.800
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5     99.800
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0     93.550
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0     94.850
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0     85.800

# %%
df['college'].value_counts()
# Out:
# college
# IITM                   2
# ANAMALAI UNIVERSITY    2
# SRM                    2
# SAVEETHA               2
# dhgvuicbh              1
# ANNA UNIVERSITY        1
# Name: count, dtype: int64

# %%
df.groupby("college")["cmark"].mean()
# Out:
# college
# ANAMALAI UNIVERSITY    76.0
# ANNA UNIVERSITY        99.0
# IITM                   85.0
# SAVEETHA               77.5
# SRM                    90.8
# dhgvuicbh              83.0
# Name: cmark, dtype: float64

# %%
df.groupby("college")["hsc"].median()
# Out:
# college
# ANAMALAI UNIVERSITY    95.60
# ANNA UNIVERSITY        88.39
# IITM                   91.95
# SAVEETHA               99.80
# SRM                    93.35
# dhgvuicbh              78.90
# Name: hsc, dtype: float64

# %%
df[(df['hsc']>85)&(df["arrears"]==0)]
# Out:
#    sl No name college   hsc  SSLC  arrears  cmark  avg_marks
# 1    1.0   A1    IITM  89.9  92.6      0.0   95.0      91.25
# 6    6.0   A6     SRM  99.8  88.1      0.0   89.6      93.95

# %%
## ADVANCED ANALYSIS

df["pass"] = df["cmark"]>=50
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark  avg_marks  \
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0     91.250
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0     93.550
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6     93.950
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5     82.800
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5     99.800
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0     94.850
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0     85.800
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0     81.900
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0     91.950
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995
#
#     pass
# 1   True
# 4   True
# 6   True
# 8   True
# 9   True
# 13  True
# 15  True
# 17  True
# 18  True
# 19  True

# %%
df[['hsc','SSLC','cmark']].corr()
# Out:
#             hsc      SSLC     cmark
# hsc    1.000000 -0.128832 -0.420064
# SSLC  -0.128832  1.000000  0.213731
# cmark -0.420064  0.213731  1.000000

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.to_csv("cleaned.csv",index = False)

# %%
df1 = pd.read_csv("cleaned.csv",chunksize = 1000)

# %%
df1

# %%
df[['name','college','cmark']]
# Out:
#    name              college  cmark
# 1    A1                 IITM   95.0
# 4    A4  ANAMALAI UNIVERSITY   76.0
# 6    A6                  SRM   89.6
# 8    A8             SAVEETHA   77.5
# 9   A34             SAVEETHA   77.5
# 13   A9  ANAMALAI UNIVERSITY   76.0
# 15  A10                 IITM   75.0
# 17  A12            dhgvuicbh   83.0
# 18  A13                  SRM   92.0
# 19   A3      ANNA UNIVERSITY   99.0

# %%
df.set_index(["sl No"])
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark  avg_marks  \
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0     91.250
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0     93.550
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6     93.950
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5     82.800
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5     99.800
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0     94.850
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0     85.800
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0     81.900
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0     91.950
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995
#
#     pass
# 1   True
# 4   True
# 6   True
# 8   True
# 9   True
# 13  True
# 15  True
# 17  True
# 18  True
# 19  True

# %%
df.nlargest(3,'cmark')
# Out:
#     sl No name          college    hsc  SSLC  arrears  cmark  avg_marks  pass
# 19    3.0   A3  ANNA UNIVERSITY  88.39  85.6      6.0   99.0     86.995  True
# 1     1.0   A1             IITM  89.90  92.6      0.0   95.0     91.250  True
# 18   14.0  A13              SRM  86.90  97.0     33.0   92.0     91.950  True

# %%
(df[df["arrears"]==0].shape[0]/df.shape[0])*100
# Out:
# 20.0
